# %% [markdown]
# <a href="https://colab.research.google.com/github/rvquel/Data110-22016/blob/main/Project1_EDA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
### Introduction
#

# %%
import matplotlib.pyplot as plt
import pandas as pd

data = pd.read_csv('hhttps://github.com/rvquel/Data110-22016/blob/main/MoCoHSdata18-19.csv?plain=1')
print(data.head())
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-98-0562dea60598> in <cell line: 4>()
#       2 import pandas as pd
#       3
# ----> 4 data = pd.read_csv('hhttps://github.com/rvquel/Data110-22016/blob/main/MoCoHSdata18-19.csv?plain=1')
#       5 print(data.head())
#
# ...

# %%
from matplotlib import pyplot as plt
import numpy as np
import pandas as pd
plt.style.use("ggplot")

# Load the dataset
file_path = '/mnt/data/MoCoHSdata18-19.csv'

# %%
school_names = ['Schoolname']
allocated_costs = ['total allocated cost']

# Plotting the bar chart for total allocated cost per school
plt.figure(figsize=(12, 8))
plt.barh(school_names, allocated_costs, color='blue')
plt.xlabel('Total Allocated Cost')
plt.ylabel('School Name')
plt.title('Total Allocated Cost per School')
plt.gca().invert_yaxis()
plt.show()

# %%
# Adjusting for any extra spaces in column names
race_categories = ['% white', '% black ', '% hispanic/latinx', '% asian']

# Plotting the pie chart
plt.figure(figsize=(8, 8))
plt.title('Distribution of Race Types in Student Population')
plt.show()
